# %% [markdown]
# # <span style="color:lightblue">PREDICTING BANK PRODUCT SUBSCRIPTION</span>

# %% [markdown]
# Authors:
#
# - Miguel Ramos Cabañas 100473854
#
# - Miguel Rodríguez Losada 100568756

# %% [markdown]
# ##  <span style="color:#0066CC">Libraries Import</span>

# %% [markdown]
# Before starting the analysis, we first import all the libraries we’ll need throughout the assignment.
# These include basic tools for working with data (like pandas and numpy), plotting (matplotlib), and building machine-learning models (scikit-learn).
# Having all the imports together at the beginning keeps the notebook organized and makes it easier to see which tools we are using.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from statsmodels.stats.proportion import proportion_confint
import optuna
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
import optuna
import pandas as pd
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder, FunctionTransformer
from sklearn.metrics import accuracy_score

# %% [markdown]
# ##  <span style="color:#0066CC"> Data Import</span>

# %% [markdown]
# We use the last 2 digits from the NIA from the first author. As a consequence, we select the data folder **bank_54**.
#
# For convenience and ease of manipulation, the data are loaded into a pandas DataFrame.

# %%
data = pd.read_pickle("P1_assignment_dataset_bank_ALL/bank_54.pkl")

print(data.head())
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %% [markdown]
# ##  <span style="color:#0066CC"> Simplified EDA</span>

# %% [markdown]
# Before exploring the data, it is useful to understand what each variable represents.
# The table below summarizes all the columns in the dataset, including client information, campaign details, and the target variable deposit.
#
# | Variable | Short Description |
# | :--- | :--- |
# | **age** | age in years |
# | **job** | type of job |
# | **marital** | marital status |
# | **education** | education level |
# | **default** | has credit in default? |
# | **balance** | average yearly balance |
# | **housing** | has a housing loan? |
# | **loan** | has a personal loan? |
# | **contact** | contact communication type |
# | **day_of_week** | last contact day |
# | **month** | last contact month |
# | **duration** | last contact duration, in seconds |
# | **campaign** | number of contacts performed during this campaign and for this client |
# | **pdays** | number of days that passed by after the client was last contacted from a previous campaign. The value is -1 if no/unknown contact was produced. |
# | **previous** | number of contacts performed before this campaign and for this client |
# | **poutcome** | outcome of the previous marketing campaign |
# | **deposit** | has the client subscribed a term deposit? **TARGET VARIABLE** |

# %% [markdown]
# To begin the exploratory analysis, we first determine the size of the dataset by identifying the total number of instances (rows) and features (columns).

# %%
print("The number of instances (rows) in the dataset is", len(data), "and the number of features (columns) is", len(data.columns))
# Out:
# The number of instances (rows) in the dataset is 11000 and the number of features (columns) is 17

# %% [markdown]
# Also, it is important to understand the type of each variable in the dataset.
# This helps us decide how to handle them later: for example, numerical features may require scaling, while categorical features need encoding.
#
# In the following step, we separate the variables into two groups:
# - **Numerical variables** (integers or floats)
# - **Categorical variables** (strings or objects)

# %%
numerical_cols = data.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = data.select_dtypes(include=['object']).columns.tolist()

print("Numerical variables:", numerical_cols)
print("Categorical variables:", categorical_cols)
# Out:
# Numerical variables: ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']
# Categorical variables: ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome', 'deposit']

# %% [markdown]
# In the following step, we compute the number of unique values for each categorical feature to detect potential high-cardinality columns.

# %%
unique_counts = {col: data[col].nunique() for col in categorical_cols}

print("Number of unique categories per categorical variable:")
for col, count in unique_counts.items():
    print(f"{col}: {count}")
# Out:
# Number of unique categories per categorical variable:
# job: 12
# marital: 3
# education: 4
# default: 2
# housing: 2
# loan: 2
# contact: 3
# month: 12
# poutcome: 4
# deposit: 2

# %% [markdown]
# We next examine the presence of missing values and identify any features that may need special treatment.
# Specifically, we check:
# - whether any variables contain missing entries,
# - whether any columns are constant (i.e., have only one unique value), and
# - whether any column behaves like an identifier, containing a different value for every row.

# %%
missing_values = data.isna().sum()
print("Missing values per column:")
print(missing_values)
# Out:
# Missing values per column:
# age            0
# job            0
# marital      538
# education      0
# default        0
# balance        0
# housing        0
# loan           0
# contact        0
# day            0
# month          0
# duration       0
# campaign       0
# pdays          0
# previous       0
# poutcome       0
# deposit        0
# dtype: int64

# %%
constant_cols = [col for col in data.columns if data[col].nunique() == 1]
print("\nConstant columns:")
print(constant_cols)
# Out:
# Constant columns:
# []
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
id_like_cols = [col for col in data.columns if data[col].nunique() == len(data)]
print("\nID-like columns:")
print(id_like_cols)
# Out:
# ID-like columns:
# []
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# From the missing-value analysis, we observe that all variables except one are complete.
# The only feature containing missing data is **marital**, with 538 missing entries.
# This means we will need to decide later whether to impute these values or apply another preprocessing strategy.
#
# We also checked for constant columns, and none were found. This is good because it means every feature contributes at least some variability to the dataset.
#
# Finally, there are no ID-like columns, so the dataset does not include fields that uniquely identify each row.
# This confirms that all variables are potentially useful for modelling and that no column needs to be removed for behaving like an identifier.

# %% [markdown]
# After this initial inspection of the dataset, we can verify that the task corresponds to a **binary classification problem**, where the target variable deposit takes two possible values: yes or no.
#
# The objective is to predict whether a client has subscribed to a term deposit based on the available features.

# %% [markdown]
# To verify whether the classification problem is imbalanced, we examine the class proportions of the target variable deposit.
#
# This will be a key point to determine the strategy for the outer and inner evaluation.

# %%
data['deposit'].value_counts(normalize=True)
# Out:
# deposit
# no     0.525455
# yes    0.474545
# Name: proportion, dtype: float64
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# The target variable shows a proportion of approximately 52.5% for "no" and 47.5% for "yes".
# This distribution is relatively balanced, meaning we do not need any special imbalanced-learning techniques.

# %% [markdown]
# The variable `pdays` indicates the number of days since the client was last contacted in a previous campaign.
# A value of **–1** means the client was never contacted.

# %%
print(data['pdays'].describe())
# Out:
# count    11000.000000
# mean        51.308636
# std        108.782842
# min         -1.000000
# 25%         -1.000000
# 50%         -1.000000
# 75%         20.250000
# max        854.000000
# Name: pdays, dtype: float64
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Most values are –1, meaning the variable is highly skewed and not suitable as a standard numerical feature.
#
# A good strategy to simplify its interpretation, we create a binary variable:
#
# - 1 → client was previously contacted
# - 0 → client was never contacted
#
# This captures the relevant information without misinterpreting –1 as a real day count.

# %%
# Binary transformation of pdays
data['pdays_contacted'] = (data['pdays'] != -1).astype(int)

# Quick check
data['pdays_contacted'].value_counts()
# Out:
# pdays_contacted
# 0    8203
# 1    2797
# Name: count, dtype: int64

# %% [markdown]
# ##  <span style="color:#0066CC"> Definition of the outer and inner evaluation EDA</span>

# %% [markdown]
# %%%%% Teño que redactar aquí

# %% [markdown]
# ### Códigos ayuda

# %% [markdown]
# ### Outer evaluation

# %%
# 1. ANALYSIS FUNCTION 
def analyze_test_accuracy(data, target_col, test_sizes=[0.05, 0.1, 0.15, 0.2, 0.25, 0.3]):
    """
    We analyze the effect of different test sizes on accuracy estimates using a decision tree.
    We return a DataFrame including estimated accuracy, Clopper-Pearson confidence intervals, and their widths.
    Note: This methology was extracted from the notion of Binomial/Beta distribution in Topic 3 for selecting optimal test size.
    """
    X = data.drop(columns=[target_col])
    y = data[target_col]


    # Identify categorical columns and apply OneHotEncoder
    cat_cols = X.select_dtypes(include=['object', 'category']).columns
    preprocessor = ColumnTransformer(
        transformers=[
            ('cat', OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore'), cat_cols)
        ],
        remainder='passthrough',
        verbose_feature_names_out=False
    )

    print("Applying OneHotEncoder...")
    X_array = preprocessor.fit_transform(X)

    # Attempt to retrieve feature names
    try:
        feature_names = preprocessor.get_feature_names_out()
    except:
        feature_names = [f"feat_{i}" for i in range(X_array.shape[1])]

    X = pd.DataFrame(X_array, columns=feature_names)

    results = []
    print(f"Analyzing dataset with {len(data)} total instances...\n")

    for test_size in test_sizes:
        # Train/Test split
        X_train, X_test, y_train, y_test = train_test_split(
            X, y, test_size=test_size, stratify=y, random_state=100473854
        )

        # Fit a decision tree as a proxy model
        clf = DecisionTreeClassifier(random_state=100473854, max_depth=5)
        clf.fit(X_train, y_train)

        # Compute accuracy and confidence intervals
        y_pred = clf.predict(X_test)
        n_test = len(y_test)
        correct_predictions = np.sum(y_pred == y_test)
        accuracy = correct_predictions / n_test

        # Clopper-Pearson (Beta) confidence interval
        ci_low, ci_high = proportion_confint(correct_predictions, n_test, alpha=0.05, method='beta')
        width = ci_high - ci_low

        # We store exact numerical values to ensure plotting accuracy
        results.append({
            'Test Size %': int(test_size*100),
            'N Test': n_test,
            'N Train': len(y_train),
            'Accuracy Est.': accuracy,
            'CI Low': ci_low,
            'CI High': ci_high,
            'CI Width': width
        })

    return pd.DataFrame(results)

# %%
# 2. PLOTTING FUNCTION
def plot_results(df, optimal_pct=15):
    """
    We visualize the accuracy estimates and confidence intervals for different test sizes.
    The first plot shows uncertainty vs. test size; the second shows error bars for estimated accuracy.
    """
    plt.style.use('seaborn-v0_8-whitegrid')
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

    # -- PLOT 1: Uncertainty Curve --
    sizes = df['Test Size %']
    widths = df['CI Width']
    ax1.plot(sizes, widths, marker='o', linestyle='-', color='gray', label='Interval Width')

    # Highlight the optimal test size
    row_opt = df[df['Test Size %'] == optimal_pct]
    if not row_opt.empty:
        val_width = row_opt['CI Width'].values[0]
        ax1.scatter(optimal_pct, val_width, color='red', s=150, zorder=5, label=f'Selection ({optimal_pct}%)')
        ax1.axvline(x=optimal_pct, color='red', linestyle='--', alpha=0.5)
        ax1.annotate(f'Width: {val_width:.4f}',
                     xy=(optimal_pct, val_width), xytext=(optimal_pct+2, val_width+0.01),
                     arrowprops=dict(facecolor='black', shrink=0.05))

    ax1.set_title('Uncertainty vs. Test Size\n(Smaller Width is Better)', fontsize=12, fontweight='bold')
    ax1.set_xlabel('Test Size (%)')
    ax1.set_ylabel('Interval Width')
    ax1.legend()

    # -- PLOT 2: Error Bars for Accuracy --
    y_err_low = df['Accuracy Est.'] - df['CI Low']
    y_err_high = df['CI High'] - df['Accuracy Est.']
    error_bars = [y_err_low, y_err_high]
    colors = ['red' if s == optimal_pct else 'skyblue' for s in sizes]

    ax2.errorbar(sizes, df['Accuracy Est.'], yerr=error_bars, fmt='none', ecolor='gray', elinewidth=2, capsize=5)
    ax2.scatter(sizes, df['Accuracy Est.'], s=100, c=colors, zorder=3)

    ax2.set_title('Statistical Accuracy (Real Confidence Intervals)', fontsize=12, fontweight='bold')
    ax2.set_xlabel('Test Size (%)')
    ax2.set_ylabel('Accuracy')

    plt.tight_layout()
    plt.show()

# %%
# MAIN EXECUTION
try:
    # 1. Run analysis (using the updated function above)
    df_res = analyze_test_accuracy(data, "deposit")  

    # 2. Print results table
    print("Results Table:")
    print_df = df_res.copy()
    print_df['CI 95% Text'] = print_df.apply(lambda x: f"[{x['CI Low']:.4f}, {x['CI High']:.4f}]", axis=1)
    cols_show = ['Test Size %', 'N Test', 'N Train', 'Accuracy Est.', 'CI 95% Text', 'CI Width']
    print(print_df[cols_show].to_string(index=False))

    # 3. Generate plots
    print("\nGenerating plots...")
    plot_results(df_res, optimal_pct=15)

except NameError:
    print("Error: Please ensure the variable 'data' is loaded before running.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Applying OneHotEncoder...
# Analyzing dataset with 11000 total instances...
#
# Results Table:
#  Test Size %  N Test  N Train  Accuracy Est.      CI 95% Text  CI Width
#            5     550    10450       0.796364 [0.7602, 0.8293]  0.069014
#           10    1100     9900       0.792727 [0.7676, 0.8163]  0.048777
#           15    1650     9350       0.800000 [0.7799, 0.8191]  0.039186
#           20    2200     8800       0.807727 [0.7906, 0.8240]  0.033377
#           25    2750     8250       0.818182 [0.8032, 0.8324]  0.029186
#           30    3300     7700       0.815152 [0.8015, 0.8283]  0.026784
#
# Generating plots...

# %% [markdown]
# Based on the results, we have selected as an optimal partition 85% for training and 15% for testing.

# %%
X = data.drop(columns='deposit') 
y = data['deposit']

# Split 85% train, 15% test: Optimal test size from analysis
X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    test_size=0.15,  
    random_state=100473854, 
    stratify=y       
)

print("Size X_train:", X_train.shape)
print("Size X_test:", X_test.shape)
# Out:
# Size X_train: (9350, 17)
# Size X_test: (1650, 17)

# %% [markdown]
# ### Inner evaluation

# %% [markdown]
# We must create a variable called optimal_cv for the pipelines

# %%
optimal_cv = 5

# %% [markdown]
# ## Basic Methods

# %% [markdown]
# ### KNN

# %% [markdown]
# ### TREES

# %% [markdown]
# ## Advanced Methods

# %% [markdown]
# ### Random Forest

# %%
# According to the previous analysis, the variable pdays has a lot of -1 values indicating no prior contact. 
# As a consequence, we will create a new binary feature pdays_contacted indicating whether the client has been contacted before or not.
def add_pdays_contacted(X):
    if 'pdays' in X.columns:
        X['pdays_contacted'] = (X['pdays'] != -1).astype(int)
    return X

# Wrap in FunctionTransformer. 
# validate=False allows X to be passed as a DataFrame rather than converted to numpy first.
pdays_transformer = FunctionTransformer(add_pdays_contacted, validate=False)

# We define the CASH Objective Function for the HPO
def objective(trial):
    # Define Preprocessing Structure
    # We must define which columns go where. 
    numerical_cols = X_train.select_dtypes(include=['int64', 'float64']).columns.tolist()
    categorical_cols = X_train.select_dtypes(include=['object']).columns.tolist()
    binary_cols = ['pdays_contacted']
    numeric_cols = [col for col in numerical_cols if col not in binary_cols]
    categorical_cols = categorical_cols

    # Optimization: Choose Scaler for Numeric Data
    scaler_name = trial.suggest_categorical("scaler", ["StandardScaler", "MinMaxScaler", "None"])
    
    if scaler_name == "StandardScaler":
        scaler = StandardScaler()
    elif scaler_name == "MinMaxScaler":
        scaler = MinMaxScaler()
    else:
        scaler = 'passthrough'

    # The ColumnTransformer applies the chosen scaler to numerics
    # and handles the others (OneHot for categorical, passthrough for binary)
    preprocessor = ColumnTransformer(
        transformers=[
            ('num', scaler, numeric_cols),
            ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols),
            ('bin', 'passthrough', binary_cols) 
        ]
    )

    # Define Hyperparameters
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 2, 30),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 15),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
        'criterion': trial.suggest_categorical('criterion', ['gini', 'entropy'])
    }
    
    clf = RandomForestClassifier(random_state=100473854, **params)

    # Build the Full Pipeline 
    pipeline = Pipeline(steps=[
        ('feature_engineering', pdays_transformer),
        ('preprocessor', preprocessor),
        ('classifier', clf)
    ])

    # Inner Evaluation Cross-Validation 
    cv = StratifiedKFold(n_splits= optimal_cv, shuffle=True, random_state=100473854) # The number of folds must be fixed in a previous part from the project
    scores = cross_val_score(pipeline, X_train, y_train, cv=cv, scoring='accuracy')
    
    return scores.mean()

# %%
# Run Optimization
print("--- Starting Optuna Optimization ---")
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=30) 

print(f"\nBest CV Accuracy: {study.best_value:.4f}")
print(f"Best Parameters: {study.best_params}")


# Final Evaluation & Comparison
# Re-build the best pipeline
best_params = study.best_params
best_scaler_name = best_params['scaler']

# Logic to recreate the scaler object
if best_scaler_name == "StandardScaler":
    final_scaler = StandardScaler()
elif best_scaler_name == "MinMaxScaler":
    final_scaler = MinMaxScaler()
else:
    final_scaler = 'passthrough'

final_preprocessor = ColumnTransformer(
    transformers=[
        ('num', final_scaler, ['age', 'balance', 'pdays']),
        ('cat', OneHotEncoder(handle_unknown='ignore'), ['job']),
        ('bin', 'passthrough', ['pdays_contacted'])
    ]
)

final_rf = RandomForestClassifier(
    n_estimators=best_params['n_estimators'],
    max_depth=best_params['max_depth'],
    min_samples_split=best_params['min_samples_split'],
    min_samples_leaf=best_params['min_samples_leaf'],
    criterion=best_params['criterion'],
    random_state=42
)

opt_pipeline = Pipeline(steps=[
    ('feature_engineering', pdays_transformer),
    ('preprocessor', final_preprocessor),
    ('classifier', final_rf)
])

opt_pipeline.fit(X_train, y_train)
acc_opt = accuracy_score(y_train, opt_pipeline.predict(X_train))

# Baseline (Default RF without custom feature engineering or HPO)
# Note: Baseline needs OneHotEncoder to work at all, but no pdays_contacted
baseline_preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), ['job'])
    ], remainder='passthrough' 
)
base_pipeline = Pipeline(steps=[
    ('preprocessor', baseline_preprocessor),
    ('classifier', RandomForestClassifier(random_state=100473854))
])
base_pipeline.fit(X_train, y_train)
acc_base = accuracy_score(y_train, base_pipeline.predict(X_train))

print(f"\n--- Final Comparison ---")
print(f"Baseline Accuracy:  {acc_base:.4f}")
print(f"Optimized Accuracy: {acc_opt:.4f}")
print(f"Improvement:        {acc_opt - acc_base:.4f}")
# Out:
# [I 2025-12-03 12:46:33,819] A new study created in memory with name: no-name-5d5c2b1f-163b-42e7-86f3-5a80f612f49a
# --- Starting Optuna Optimization ---
# [I 2025-12-03 12:46:44,821] Trial 0 finished with value: 0.8510160427807486 and parameters: {'scaler': 'None', 'n_estimators': 130, 'max_depth': 16, 'min_samples_split': 14, 'min_samples_leaf': 8, 'criterion': 'gini'}. Best is trial 0 with value: 0.8510160427807486.
# [I 2025-12-03 12:46:51,357] Trial 1 finished with value: 0.8427807486631016 and parameters: {'scaler': 'StandardScaler', 'n_estimators': 113, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 8, 'criterion': 'gini'}. Best is trial 0 with value: 0.8510160427807486.
# [I 2025-12-03 12:47:13,563] Trial 2 finished with value: 0.8478074866310159 and parameters: {'scaler': 'MinMaxScaler', 'n_estimators': 268, 'max_depth': 12, 'min_samples_split': 15, 'min_samples_leaf': 8, 'criterion': 'entropy'}. Best is trial 0 with value: 0.8510160427807486.
# [I 2025-12-03 12:47:30,783] Trial 3 finished with value: 0.8522994652406417 and parameters: {'scaler': 'MinMaxScaler', 'n_estimators': 195, 'max_depth': 23, 'min_samples_split': 15, 'min_samples_leaf': 6, 'criterion': 'entropy'}. Best is trial 3 with value: 0.8522994652406417.
# [I 2025-12-03 12:47:37,046] Trial 4 finished with value: 0.8442780748663102 and parameters: {'scaler': 'None', 'n_estimators': 93, 'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 4, 'criterion': 'gini'}. Best is trial 3 with value: 0.8522994652406417.
# [I 2025-12-03 12:47:56,894] Trial 5 finished with value: 0.8533689839572194 and parameters: {'scaler': 'None', 'n_estimators': 214, 'max_depth': 19, 'min_samples_split': 11, 'min_samples_leaf': 5, 'criterion': 'entropy'}. Best is trial 5 with value: 0.8533689839572194.
# [I 2025-12-03 12:48:11,694] Trial 6 finished with value: 0.8516577540106951 and parameters: {'scaler': 'MinMaxScaler', 'n_estimators': 154, 'max_depth': 15, 'min_samples_split': 14, 'min_samples_leaf': 5, 'criterion': 'entropy'}. Best is trial 5 with value: 0.8533689839572194.
# [I 2025-12-03 12:48:21,441] Trial 7 finished with value: 0.8484491978609625 and parameters: {'scaler': 'None', 'n_estimators': 122, 'max_depth': 10, 'min_samples_split': 12, 'min_samples_leaf': 3, 'criterion': 'entropy'}. Best is trial 5 with value: 0.8533689839572194.
# [I 2025-12-03 12:48:27,517] Trial 8 finished with value: 0.8310160427807487 and parameters: {'scaler': 'StandardScaler', 'n_estimators': 119, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 6, 'criterion': 'gini'}. Best is trial 5 with value: 0.8533689839572194.
# [I 2025-12-03 12:48:38,510] Trial 9 finished with value: 0.8551871657754011 and parameters: {'scaler': 'None', 'n_estimators': 96, 'max_depth': 23, 'min_samples_split': 5, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 9 with value: 0.8551871657754011.
# [I 2025-12-03 12:48:44,990] Trial 10 finished with value: 0.8566844919786096 and parameters: {'scaler': 'None', 'n_estimators': 53, 'max_depth': 30, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 10 with value: 0.8566844919786096.
# [I 2025-12-03 12:48:52,749] Trial 11 finished with value: 0.8574331550802139 and parameters: {'scaler': 'None', 'n_estimators': 58, 'max_depth': 30, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 11 with value: 0.8574331550802139.
# [I 2025-12-03 12:48:57,777] Trial 12 finished with value: 0.8560427807486631 and parameters: {'scaler': 'None', 'n_estimators': 50, 'max_depth': 30, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 11 with value: 0.8574331550802139.
# [I 2025-12-03 12:49:04,761] Trial 13 finished with value: 0.8575401069518716 and parameters: {'scaler': 'None', 'n_estimators': 68, 'max_depth': 30, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 13 with value: 0.8575401069518716.
# [I 2025-12-03 12:49:12,227] Trial 14 finished with value: 0.8545454545454545 and parameters: {'scaler': 'None', 'n_estimators': 77, 'max_depth': 25, 'min_samples_split': 8, 'min_samples_leaf': 3, 'criterion': 'entropy'}. Best is trial 13 with value: 0.8575401069518716.
# [I 2025-12-03 12:49:29,412] Trial 15 finished with value: 0.8605347593582888 and parameters: {'scaler': 'StandardScaler', 'n_estimators': 161, 'max_depth': 27, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 15 with value: 0.8605347593582888.
# [I 2025-12-03 12:49:58,512] Trial 16 finished with value: 0.8555080213903743 and parameters: {'scaler': 'StandardScaler', 'n_estimators': 247, 'max_depth': 26, 'min_samples_split': 2, 'min_samples_leaf': 3, 'criterion': 'entropy'}. Best is trial 15 with value: 0.8605347593582888.
# [I 2025-12-03 12:50:04,451] Trial 17 finished with value: 0.749946524064171 and parameters: {'scaler': 'StandardScaler', 'n_estimators': 156, 'max_depth': 2, 'min_samples_split': 9, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 15 with value: 0.8605347593582888.
# [I 2025-12-03 12:50:25,798] Trial 18 finished with value: 0.8560427807486631 and parameters: {'scaler': 'StandardScaler', 'n_estimators': 219, 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 2, 'criterion': 'gini'}. Best is trial 15 with value: 0.8605347593582888.
# [I 2025-12-03 12:50:54,686] Trial 19 finished with value: 0.8550802139037433 and parameters: {'scaler': 'StandardScaler', 'n_estimators': 293, 'max_depth': 27, 'min_samples_split': 4, 'min_samples_leaf': 4, 'criterion': 'entropy'}. Best is trial 15 with value: 0.8605347593582888.
# [I 2025-12-03 12:51:07,657] Trial 20 finished with value: 0.8506951871657755 and parameters: {'scaler': 'StandardScaler', 'n_estimators': 160, 'max_depth': 20, 'min_samples_split': 8, 'min_samples_leaf': 7, 'criterion': 'entropy'}. Best is trial 15 with value: 0.8605347593582888.
# [I 2025-12-03 12:51:13,544] Trial 21 finished with value: 0.8497326203208555 and parameters: {'scaler': 'None', 'n_estimators': 74, 'max_depth': 28, 'min_samples_split': 6, 'min_samples_leaf': 10, 'criterion': 'entropy'}. Best is trial 15 with value: 0.8605347593582888.
# [I 2025-12-03 12:51:20,966] Trial 22 finished with value: 0.857326203208556 and parameters: {'scaler': 'None', 'n_estimators': 72, 'max_depth': 30, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 15 with value: 0.8605347593582888.
# [I 2025-12-03 12:51:40,493] Trial 23 finished with value: 0.8592513368983956 and parameters: {'scaler': 'MinMaxScaler', 'n_estimators': 182, 'max_depth': 24, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 15 with value: 0.8605347593582888.
# [I 2025-12-03 12:52:04,307] Trial 24 finished with value: 0.8560427807486631 and parameters: {'scaler': 'MinMaxScaler', 'n_estimators': 186, 'max_depth': 24, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 15 with value: 0.8605347593582888.
# [I 2025-12-03 12:52:30,686] Trial 25 finished with value: 0.8566844919786096 and parameters: {'scaler': 'MinMaxScaler', 'n_estimators': 226, 'max_depth': 22, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 15 with value: 0.8605347593582888.
# [I 2025-12-03 12:52:43,492] Trial 26 finished with value: 0.8519786096256684 and parameters: {'scaler': 'MinMaxScaler', 'n_estimators': 142, 'max_depth': 27, 'min_samples_split': 2, 'min_samples_leaf': 4, 'criterion': 'gini'}. Best is trial 15 with value: 0.8605347593582888.
# [I 2025-12-03 12:53:05,277] Trial 27 finished with value: 0.8562566844919786 and parameters: {'scaler': 'MinMaxScaler', 'n_estimators': 174, 'max_depth': 27, 'min_samples_split': 5, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 15 with value: 0.8605347593582888.
# [I 2025-12-03 12:53:29,126] Trial 28 finished with value: 0.855614973262032 and parameters: {'scaler': 'StandardScaler', 'n_estimators': 205, 'max_depth': 21, 'min_samples_split': 3, 'min_samples_leaf': 3, 'criterion': 'entropy'}. Best is trial 15 with value: 0.8605347593582888.
# [I 2025-12-03 12:53:43,272] Trial 29 finished with value: 0.8493048128342247 and parameters: {'scaler': 'MinMaxScaler', 'n_estimators': 175, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 10, 'criterion': 'gini'}. Best is trial 15 with value: 0.8605347593582888.
# Best CV Accuracy: 0.8605
# Best Parameters: {'scaler': 'StandardScaler', 'n_estimators': 161, 'max_depth': 27, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy'}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 60
#      51 baseline_preprocessor = ColumnTransformer(
#      52     transformers=[
#      53         ('cat', OneHotEncoder(handle_unknown='ignore'), ['job'])
#      54     ], remainder='passthrough'
#      55 )
#      56 base_pipeline = Pipeline(steps=[
#      57     ('preprocessor', baseline_preprocessor),
#      58     ('classifier', RandomForestClassifier(random_state=100473854))
#      59 ])
# ---> 60 base_pipeline.fit(X_train, y_train)
#      61 acc_base = accuracy_score(y_train, base_pipeline.predict(X_train))
#      63 print(f"\n--- Final Comparison ---")
#
# File c:\Users\Migue\anaconda3\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Migue\anaconda3\Lib\site-packages\sklearn\pipeline.py:475, in Pipeline.fit(self, X, y, **params)
#     473     if self._final_estimator != "passthrough":
#     474         last_step_params = routed_params[self.steps[-1][0]]
# --> 475         self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     477 return self
#
# File c:\Users\Migue\anaconda3\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Migue\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:363, in BaseForest.fit(self, X, y, sample_weight)
#     360 if issparse(y):
#     361     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 363 X, y = self._validate_data(
#     364     X,
#     365     y,
#     366     multi_output=True,
#     367     accept_sparse="csc",
#     368     dtype=DTYPE,
#     369     force_all_finite=False,
#     370 )
#     371 # _compute_missing_values_in_feature_mask checks if X has missing values and
#     372 # will raise an error if the underlying tree base estimator can't handle missing
#     373 # values. Only the criterion is required to determine if the tree supports
#     374 # missing values.
#     375 estimator = type(self.estimator)(criterion=self.criterion)
#
# File c:\Users\Migue\anaconda3\Lib\site-packages\sklearn\base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File c:\Users\Migue\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1263, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1258         estimator_name = _check_estimator_name(estimator)
#    1259     raise ValueError(
#    1260         f"{estimator_name} requires y to be passed, but the target y is None"
#    1261     )
# -> 1263 X = check_array(
#    1264     X,
#    1265     accept_sparse=accept_sparse,
#    1266     accept_large_sparse=accept_large_sparse,
#    1267     dtype=dtype,
#    1268     order=order,
#    1269     copy=copy,
#    1270     force_all_finite=force_all_finite,
#    1271     ensure_2d=ensure_2d,
#    1272     allow_nd=allow_nd,
#    1273     ensure_min_samples=ensure_min_samples,
#    1274     ensure_min_features=ensure_min_features,
#    1275     estimator=estimator,
#    1276     input_name="X",
#    1277 )
#    1279 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1281 check_consistent_length(X, y)
#
# File c:\Users\Migue\anaconda3\Lib\site-packages\sklearn\utils\validation.py:997, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     995         array = xp.astype(array, dtype, copy=False)
#     996     else:
# --> 997         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     998 except ComplexWarning as complex_warning:
#     999     raise ValueError(
#    1000         "Complex data not supported\n{}\n".format(array)
#    1001     ) from complex_warning
#
# File c:\Users\Migue\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py:521, in _asarray_with_order(array, dtype, order, copy, xp)
#     519     array = numpy.array(array, order=order, dtype=dtype)
#     520 else:
# --> 521     array = numpy.asarray(array, order=order, dtype=dtype)
#     523 # At this point array is a NumPy ndarray. We convert it to an array
#     524 # container that is consistent with the input's namespace.
#     525 return xp.asarray(array)
#
# ValueError: could not convert string to float: 'married'

# %% [markdown]
# ### Gradient Boosting

# %% [markdown]
# ## Results and Final Model

# %% [markdown]
# ## Probability Calibration

# %% [markdown]
# ## Open Choice Task
